# %%
from bookinz.storage import BookingBronzeLayer, BookingSilverLayer
bl = BookingBronzeLayer("data")
sl = BookingSilverLayer("data")

# Bronze (raw scraped rows)
df = bl.query("SELECT * FROM booking_bronze WHERE search_area = 'Roma__Italy'")

# Silver (cleaned, deduplicated)
df = sl.query("SELECT * FROM booking_silver ORDER BY quality_price_score DESC")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from bookinz.storage import BookingBronzeLayer, BookingSilverLayer
#       2 bl = BookingBronzeLayer("data")
#       3 sl = BookingSilverLayer("data")
#       4
#
# File ~\OneDrive\Desktop\PAO800A_REPO\BOOKINZ\Bookinz\src\bookinz\storage\__init__.py:4
#       1 """Storage sub-package."""
#       3 from bookinz.storage.booking_bronze_layer import BRONZE_SCHEMA, BronzeLayer
# ----> 4 from bookinz.storage.booking_silver_layer import SILVER_SCHEMA, SilverLayer
#       5 from bookinz.storage.airbnb_bronze_layer import AIRBNB_BRONZE_SCHEMA, AirbnbBronzeLayer
#       6 from bookinz.storage.airbnb_silver_layer import AIRBNB_SILVER_SCHEMA, AirbnbSilverLayer
#
# ImportError: cannot import name 'SilverLayer' from 'bookinz.storage.booking_silver_layer' (C:\Users\gsppp\OneDrive\Desktop\PAO800A_REPO\BOOKINZ\Bookinz\src\bookinz\storage\booking_silver_layer.py)

# %%
df
# Out:
#                                             facility_id  \
# 0                             the-heritage-villa-tirana
# 1                                            vila-masha
# 2                                  damsi-loft-apartment
# 3                                            dianahome2
# 4                                     dedja-apartment-1
# ...                                                 ...
# 1912  tomato-urban-retreat-ostello-della-gioventu-roma1
# 1913                           luxury-love-apartments-3
# 1914                             dipinto-di-blu-termini
# 1915                                       mati-shelter
# 1916                   domus-picta-roomy-apartment-roma
#
#                                                     url  \
# 0     https://www.booking.com/hotel/al/the-heritage-...
# 1     https://www.booking.com/hotel/al/vila-masha.en...
# 2     https://www.booking.com/hotel/al/damsi-loft-ap...
# 3     https://www.booking.com/hotel/al/dianahome2.en...
# 4     https://www.booking.com/hotel/al/dedja-apartme...
# ...                                                 ...
# 1912  https://www.booking.com/hotel/it/tomato-urban-...
# 1913  https://www.booking.com/hotel/al/luxury-love-a...
# 1914  https://www.booking.com/hotel/it/dipinto-di-bl...
# 1915  https://www.booking.com/hotel/it/mati-shelter....
# 1916  https://www.booking.com/hotel/it/domus-picta-r...
#
#                                                name     accommodation_type  \
# 0                         The Heritage Villa Tirana           Entire villa
# 1                                        Vila Masha           Entire villa
# 2                              Damsi Loft Apartment       Entire apartment
# 3                                        DianaHome2       Entire apartment
# 4                              Elite Flats Tirana 1       Entire apartment
# ...                                             ...                    ...
# 1912  Tomato Urban Retreat - Ostello della gioventù  Shared dormitory room
# 1913                       Luxury Love Apartments 3       Entire apartment
# 1914                         Dipinto di Blu Termini       Entire apartment
# 1915                                   Mati Shelter       Entire apartment
# 1916                    Domus Picta Roomy Apartment       Entire apartment
#
#         city  country                                 neighbourhood  \
# 0     Tirana  Albania                                        Tirana
# 1     Tirana  Albania                                        Tirana
# 2     Tirana  Albania                                        Tirana
# 3     Tirana  Albania                                        Tirana
# 4     Tirana  Albania                                        Tirana
# ...      ...      ...                                           ...
# 1912    Roma    Italy  Rome • 500 m from Rome Termini Train Station
# 1913  Tirana  Albania                                        Tirana
# 1914    Roma    Italy                                          Rome
# 1915    Roma    Italy                                          Rome
# 1916    Roma    Italy                                          Rome
#
#       distance_from_center_km checkin_date checkout_date  ...  \
# 0                         1.8   2026-09-20    2026-09-27  ...
# 1                         3.0   2026-09-20    2026-09-27  ...
# 2                         3.6   2026-09-20    2026-09-27  ...
# 3                         2.6   2026-09-20    2026-09-27  ...
# 4                         2.5   2026-09-20    2026-09-27  ...
# ...                       ...          ...           ...  ...
# 1912                      NaN   2026-07-16    2026-07-22  ...
# 1913                      3.1   2026-09-20    2026-09-27  ...
# 1914                      0.6   2026-07-16    2026-07-22  ...
# 1915                      4.5   2026-07-16    2026-07-22  ...
# 1916                      0.6   2026-07-16    2026-07-22  ...
#
#       price_per_night  price_per_adult price_per_adult_per_night  rating  \
# 0               38.29            53.60                      7.66    10.0
# 1               25.86            36.20                      5.17     6.6
# 2               38.29            53.60                      7.66     9.5
# 3               43.57            61.00                      8.71    10.0
# 4               42.57            59.60                      8.51     9.3
# ...               ...              ...                       ...     ...
# 1912           128.17           192.25                     32.04     NaN
# 1913            40.00            56.00                      8.00     NaN
# 1914           619.67           929.50                    154.92     NaN
# 1915           228.00           342.00                     57.00     NaN
# 1916           441.33           662.00                    110.33     NaN
#
#       quality_price_score  num_reviews  num_rooms_available  is_available  \
# 0                1.000000            6                 <NA>          True
# 1                0.977819            5                 <NA>          True
# 2                0.949880            2                 <NA>          True
# 3                0.879160            4                 <NA>          True
# 4                0.836718            3                 <NA>          True
# ...                   ...          ...                  ...           ...
# 1912                  NaN         <NA>                 <NA>          True
# 1913                  NaN         <NA>                 <NA>          True
# 1914                  NaN         <NA>                 <NA>          True
# 1915                  NaN         <NA>                 <NA>          True
# 1916                  NaN         <NA>                 <NA>          True
#
#                                                     _pk  _source
# 0     BOOK/tiranaALBANIA/the_heritage_villa_tirana/2...     BOOK
# 1     BOOK/tiranaALBANIA/vila_masha/20260920_2026092...     BOOK
# 2     BOOK/tiranaALBANIA/damsi_loft_apartment/202609...     BOOK
# 3     BOOK/tiranaALBANIA/dianahome2/20260920_2026092...     BOOK
# 4     BOOK/tiranaALBANIA/dedja_apartment_1/20260920_...     BOOK
# ...                                                 ...      ...
# 1912  BOOK/romaITALY/tomato_urban_retreat_ostello_de...     BOOK
# 1913  BOOK/tiranaALBANIA/luxury_love_apartments_3/20...     BOOK
# 1914  BOOK/romaITALY/dipinto_di_blu_termini/20260716...     BOOK
# 1915  BOOK/romaITALY/mati_shelter/20260716_20260722/...     BOOK
# 1916  BOOK/romaITALY/domus_picta_roomy_apartment_rom...     BOOK
#
# [1917 rows x 24 columns]

# %%
from bookinz.storage import AirbnbBronzeLayer, AirbnbSilverLayer
ab  = AirbnbBronzeLayer("data")
as_ = AirbnbSilverLayer("data")

# Promote bronze → silver (run once after each scrape, safe to re-run)
silver_path = as_.push()
print(f"Silver written to: {silver_path}")

# Bronze (raw scraped rows)
df = ab.query("SELECT * FROM airbnb_bronze")

# Silver (cleaned, deduplicated, distances computed)
df = as_.query("SELECT * FROM airbnb_silver ORDER BY quality_price_score DESC")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 9
#       5 # Bronze
#       6 df = ab.query("SELECT * FROM airbnb_bronze WHERE search_area = 'Roma__Italy'")
#       7
#       8 # Silver
# ----> 9 df = as_.query("SELECT * FROM airbnb_silver ORDER BY quality_price_score DESC")
#
# File ~\OneDrive\Desktop\PAO800A_REPO\BOOKINZ\Bookinz\src\bookinz\storage\airbnb_silver_layer.py:249, in AirbnbSilverLayer.query(self, sql)
#     247 parquet_files = sorted(self.silver_root.glob("silver_*.parquet"))
#     248 if not parquet_files:
# --> 249     raise FileNotFoundError(
#     250         f"No AirBnB silver Parquet files found under {self.silver_root}. "
#     251         "Run AirbnbSilverLayer.push() first."
#     252     )
#     253 latest       = parquet_files[-1]
#     254 glob_pattern = str(latest)
#
# FileNotFoundError: No AirBnB silver Parquet files found under C:\Users\gsppp\OneDrive\Desktop\PAO800A_REPO\BOOKINZ\Bookinz\data\airbnb\silver\accommodations. Run AirbnbSilverLayer.push() first.

# %%
df
# Out:
#              facility_id                     name  \
# 0    1072712822465029350       Condo in Tuscolano
# 1    1135539785130702722  Apartment in Primavalle
# 2    1476690990400319158    Condo in Appio Latino
# 3    1616600391032718007        Apartment in Rome
# 4    1666890444030015466    Vacation home in Rome
# ..                   ...                      ...
# 294  1045548228043701774  Apartment in Pietralata
# 295  1604281160351211525        Apartment in Rome
# 296  1630541975797258430        Apartment in Rome
# 297  1163929671360251416       Condo in Portuense
# 298  1258531622624827029   Apartment in Testaccio
#
#                                                   url  search_area  \
# 0    https://www.airbnb.com/rooms/1072712822465029350  Rome__Italy
# 1    https://www.airbnb.com/rooms/1135539785130702722  Rome__Italy
# 2    https://www.airbnb.com/rooms/1476690990400319158  Rome__Italy
# 3    https://www.airbnb.com/rooms/1616600391032718007  Rome__Italy
# 4    https://www.airbnb.com/rooms/1666890444030015466  Rome__Italy
# ..                                                ...          ...
# 294  https://www.airbnb.com/rooms/1045548228043701774  Rome__Italy
# 295  https://www.airbnb.com/rooms/1604281160351211525  Rome__Italy
# 296  https://www.airbnb.com/rooms/1630541975797258430  Rome__Italy
# 297  https://www.airbnb.com/rooms/1163929671360251416  Rome__Italy
# 298  https://www.airbnb.com/rooms/1258531622624827029  Rome__Italy
#
#     checkin_date checkout_date           scraped_at  num_adults  \
# 0     2026-09-20    2026-09-27  2026-05-09T12:23:26           5
# 1     2026-09-20    2026-09-27  2026-05-09T12:23:26           5
# 2     2026-09-20    2026-09-27  2026-05-09T12:23:26           5
# 3     2026-09-20    2026-09-27  2026-05-09T12:23:26           5
# 4     2026-09-20    2026-09-27  2026-05-09T12:23:26           5
# ..           ...           ...                  ...         ...
# 294   2026-09-20    2026-09-27  2026-05-09T12:23:26           5
# 295   2026-09-20    2026-09-27  2026-05-09T12:23:26           5
# 296   2026-09-20    2026-09-27  2026-05-09T12:23:26           5
# 297   2026-09-20    2026-09-27  2026-05-09T12:23:26           5
# 298   2026-09-20    2026-09-27  2026-05-09T12:23:26           5
#
#                                            description  \
# 0    [Metro Line A Colli Albani – Appian Way] Casa ...
# 1                                     70 sqm apartment
# 2    "Dream House Charming two-room apartment \nSan...
# 3    Charming Home\nNew and spacious apartment in Rome
# 4    Luxury Apartment | 10 pax | 3 Bathrooms & Jacuzzi
# ..                                                 ...
# 294   Street Art Roma | 3BR apartment | Near Tiburtina
# 295  "Entertain ME!" MAXIscreen, BoardGames, Near M...
# 296         3 Bedrooms · 3 Private Bathrooms · Vatican
# 297                Nonna Peppina's House in Trastevere
# 298  Typical & Cozy Apartment - [Testaccio-Trastevere]
#
#                                     accommodation_type  ... rating  \
# 0    [Metro Line A Colli Albani – Appian Way] Casa ...  ...   4.92
# 1                                     70 sqm apartment  ...   4.86
# 2    "Dream House Charming two-room apartment \nSan...  ...   5.00
# 3    Charming Home\nNew and spacious apartment in Rome  ...    NaN
# 4    Luxury Apartment | 10 pax | 3 Bathrooms & Jacuzzi  ...    NaN
# ..                                                 ...  ...    ...
# 294   Street Art Roma | 3BR apartment | Near Tiburtina  ...   4.75
# 295  "Entertain ME!" MAXIscreen, BoardGames, Near M...  ...   4.78
# 296         3 Bedrooms · 3 Private Bathrooms · Vatican  ...    NaN
# 297                              Nonna Peppina's House  ...   4.98
# 298  Typical & Cozy Apartment - [Testaccio-Trastevere]  ...   4.65
#
#      num_reviews  is_superhost is_free_cancellation  \
# 0             84         False                 True
# 1             22         False                 True
# 2             29         False                 True
# 3           <NA>         False                 True
# 4           <NA>         False                 True
# ..           ...           ...                  ...
# 294           81          True                 True
# 295            9         False                 True
# 296         <NA>         False                 True
# 297           50         False                 True
# 298           23          True                 True
#
#                                   tags latitude  longitude  is_available  \
# 0    € 1,044 total, originally € 1,198      NaN        NaN          True
# 1      € 984 total, originally € 1,084      NaN        NaN          True
# 2    € 1,075 total, originally € 1,236      NaN        NaN          True
# 3    € 1,342 total, originally € 1,412      NaN        NaN          True
# 4    € 1,967 total, originally € 2,309      NaN        NaN          True
# ..                                 ...      ...        ...           ...
# 294  € 1,730 total, originally € 1,960      NaN        NaN          True
# 295                                NaN      NaN        NaN          True
# 296  € 2,203 total, originally € 2,388      NaN        NaN          True
# 297  € 2,061 total, originally € 2,225      NaN        NaN          True
# 298  € 1,637 total, originally € 1,841      NaN        NaN          True
#
#                                       raw_html_snippet  scrape_date
# 0    <div class="cy5jw6o atm_5j_112asxc atm_70_87wa...   2026-05-09
# 1    <div class="cy5jw6o atm_5j_112asxc atm_70_87wa...   2026-05-09
# 2    <div class="cy5jw6o atm_5j_112asxc atm_70_87wa...   2026-05-09
# 3    <div class="cy5jw6o atm_5j_112asxc atm_70_87wa...   2026-05-09
# 4    <div class="cy5jw6o atm_5j_112asxc atm_70_87wa...   2026-05-09
# ..                                                 ...          ...
# 294  <div class="cy5jw6o atm_5j_112asxc atm_70_87wa...   2026-05-09
# 295  <div class="cy5jw6o atm_5j_112asxc atm_70_87wa...   2026-05-09
# 296  <div class="cy5jw6o atm_5j_112asxc atm_70_87wa...   2026-05-09
# 297  <div class="cy5jw6o atm_5j_112asxc atm_70_87wa...   2026-05-09
# 298  <div class="cy5jw6o atm_5j_112asxc atm_70_87wa...   2026-05-09
#
# [299 rows x 27 columns]

# %%
query_to_silver = """
with
data_enriched as (
select
        facility_id,
        url,
        name,
        accommodation_type,
        split_part(search_area, '__', 1) as city,
        split_part(search_area, '__', 2) as country,
        neighbourhood,
        distance_from_center_km,
        checkin_date,
        checkout_date,
        date_diff('day', cast(checkin_date as date), cast(checkout_date as date)) as num_nights,
        num_adults,
        case
            when currency = '€' then 'EUR'
            when currency = '$' then 'USD'
            else currency
        end as currency,
        total_price,
        rating,
        num_reviews,
        num_rooms_available,
        is_available,
        scrape_date,
        ROW_NUMBER() OVER (
            PARTITION BY split_part(search_area, '__', 1), split_part(search_area, '__', 2), facility_id, checkin_date, checkout_date
            ORDER BY scrape_date DESC
        ) AS rn
    from bronze
),
dedup_data as (
    select
        facility_id,
        url,
        name,
        accommodation_type,
        city,
        country,
        neighbourhood,
        distance_from_center_km,
        checkin_date,
        checkout_date,
        num_nights,
        num_adults,
        currency,
        total_price,
        round(total_price / num_nights,2) as price_per_night,
        round(total_price / num_adults,2) as price_per_adult,
        round(total_price / (num_adults * num_nights),2) as price_per_adult_per_night,
        rating,
        rating / round(total_price / (num_adults * num_nights),2) as quality_price_score,
        num_reviews,
        num_rooms_available,
        is_available,
        scrape_date
    from data_enriched
    where rn = 1
),
silver as (
    select
        facility_id,
        url,
        name,
        accommodation_type,
        city,
        country,
        neighbourhood,
        distance_from_center_km,
        checkin_date,
        checkout_date,
        num_nights,
        num_adults,
        currency,
        total_price,
        price_per_night,
        price_per_adult,
        price_per_adult_per_night,
        rating,
        (
            ( quality_price_score - MIN(quality_price_score) OVER ()) )
            / 
            ( NULLIF(MAX(quality_price_score) OVER () - MIN(quality_price_score) OVER (), 0 ) 
        ) AS quality_price_score,
        num_reviews,
        num_rooms_available,
        is_available,
        cast(replace(lower(city), ' ', '_') as string) || cast(replace(upper(country), ' ', '_') as string) || '/' || cast(replace(lower(facility_id), '-', '_') as string) || '/' || cast(replace(checkin_date, '-', '') as string) || '_' || cast(replace(checkout_date, '-', '') as string) || '/' || replace(cast(scrape_date as string), '-', '') as _pk
    from dedup_data
)
select * 
from silver 
where 
    1 = 1 
    and city = 'Tirana' 
    and is_available = true
    and price_per_adult_per_night < 50
    and quality_price_score > 0.7
order by distance_from_center_km asc;
"""

# %%
bl.query(query_to_silver)
# Out:
#                                      facility_id  \
# 0                          liceu-charm-apartment
# 1                      serenity-apartment-tirana
# 2               city-charm-and-comfort-apartment
# 3                          azeo-apartment-tirana
# 4                              lolas-home-tirane
# 5                                       house-75
# 6                     new-bazar-apartment-tirane
# 7                         cheap-and-good-by-topo
# 8                                 apartment-1330
# 9   1-bed-room-apartment-don-bosko-tirane-tirent
# 10                            geljus-apartment-2
# 11                     the-heritage-villa-tirana
# 12                     ali-demi-apartment-tirane
# 13                             dedja-apartment-1
# 14                                    dianahome2
# 15                                    vila-masha
# 16                                 sunlake-villa
# 17                          damsi-loft-apartment
# 18                             villa-star-tirane
# 19                             guest-house-banaj
# 20                city-center-apartment-tirane12
#
#                                                   url  \
# 0   https://www.booking.com/hotel/al/liceu-charm-a...
# 1   https://www.booking.com/hotel/al/serenity-apar...
# 2   https://www.booking.com/hotel/al/city-charm-an...
# 3   https://www.booking.com/hotel/al/azeo-apartmen...
# 4   https://www.booking.com/hotel/al/lolas-home-ti...
# 5   https://www.booking.com/hotel/al/house-75.en-g...
# 6   https://www.booking.com/hotel/al/new-bazar-apa...
# 7   https://www.booking.com/hotel/al/cheap-and-goo...
# 8   https://www.booking.com/hotel/al/apartment-133...
# 9   https://www.booking.com/hotel/al/1-bed-room-ap...
# 10  https://www.booking.com/hotel/al/geljus-apartm...
# 11  https://www.booking.com/hotel/al/the-heritage-...
# 12  https://www.booking.com/hotel/al/ali-demi-apar...
# 13  https://www.booking.com/hotel/al/dedja-apartme...
# 14  https://www.booking.com/hotel/al/dianahome2.en...
# 15  https://www.booking.com/hotel/al/vila-masha.en...
# 16  https://www.booking.com/hotel/al/sunlake-villa...
# 17  https://www.booking.com/hotel/al/damsi-loft-ap...
# 18  https://www.booking.com/hotel/al/villa-star-ti...
# 19  https://www.booking.com/hotel/al/guest-house-b...
# 20  https://www.booking.com/hotel/al/city-center-a...
#
#                                                  name     accommodation_type  \
# 0                               Liceu Charm Apartment       Entire apartment
# 1                           Serenity Apartment Tirana       Entire apartment
# 2                                   Scutari Apartment       Entire apartment
# 3                               Azeo Apartment Tirana       Entire apartment
# 4                                        Lola's house       Entire apartment
# 5                                            House 75       Entire apartment
# 6                                 New Bazar Apartment       Entire apartment
# 7                                Cheap & Good by Topo  5 beds in dormitories
# 8                                      Apartment 1330       Entire apartment
# 9   Tirent Apartment-Cozy 2-Bedroom Stay in Don Bosko       Entire apartment
# 10                                 Geljus Apartment 2       Entire apartment
# 11                          The Heritage Villa Tirana           Entire villa
# 12                                 Ali Demi Apartment       Entire apartment
# 13                               Elite Flats Tirana 1       Entire apartment
# 14                                         DianaHome2       Entire apartment
# 15                                         Vila Masha           Entire villa
# 16                                      Sunlake Villa           Private room
# 17                               Damsi Loft Apartment       Entire apartment
# 18                                         Villa Star       Entire apartment
# 19                                 Guest House Erzeni          2 hotel rooms
# 20                       Akuena City Center Apartment       Entire apartment
#
#       city  country               neighbourhood  distance_from_center_km  \
# 0   Tirana  Albania                      Tirana                      0.9
# 1   Tirana  Albania                      Tirana                      1.0
# 2   Tirana  Albania                      Tirana                      1.1
# 3   Tirana  Albania                      Tirana                      1.1
# 4   Tirana  Albania                      Tirana                      1.2
# 5   Tirana  Albania                      Tirana                      1.3
# 6   Tirana  Albania                      Tirana                      1.3
# 7   Tirana  Albania                      Tirana                      1.5
# 8   Tirana  Albania                      Tirana                      1.6
# 9   Tirana  Albania                      Tirana                      1.7
# 10  Tirana  Albania                      Tirana                      1.7
# 11  Tirana  Albania                      Tirana                      1.8
# 12  Tirana  Albania                      Tirana                      1.8
# 13  Tirana  Albania                      Tirana                      2.5
# 14  Tirana  Albania                      Tirana                      2.6
# 15  Tirana  Albania                      Tirana                      3.0
# 16  Tirana  Albania                      Tirana                      3.3
# 17  Tirana  Albania                      Tirana                      3.6
# 18  Tirana  Albania                      Tirana                      5.1
# 19  Tirana  Albania                      Tirana                     13.2
# 20  Tirana  Albania  Tirana • 450 m from centre                      NaN
#
#    checkin_date checkout_date  ...  total_price  price_per_night  \
# 0    2026-09-20    2026-09-27  ...        321.0            45.86
# 1    2026-09-20    2026-09-27  ...        284.0            40.57
# 2    2026-09-20    2026-09-27  ...        350.0            50.00
# 3    2026-09-20    2026-09-27  ...        360.0            51.43
# 4    2026-09-20    2026-09-27  ...        357.0            51.00
# 5    2026-09-20    2026-09-27  ...        332.0            47.43
# 6    2026-09-20    2026-09-27  ...        321.0            45.86
# 7    2026-09-20    2026-09-27  ...        263.0            37.57
# 8    2026-09-20    2026-09-27  ...        327.0            46.71
# 9    2026-09-20    2026-09-27  ...        301.0            43.00
# 10   2026-09-20    2026-09-27  ...        364.0            52.00
# 11   2026-09-20    2026-09-27  ...        268.0            38.29
# 12   2026-09-20    2026-09-27  ...        327.0            46.71
# 13   2026-09-20    2026-09-27  ...        298.0            42.57
# 14   2026-09-20    2026-09-27  ...        305.0            43.57
# 15   2026-09-20    2026-09-27  ...        181.0            25.86
# 16   2026-09-20    2026-09-27  ...        357.0            51.00
# 17   2026-09-20    2026-09-27  ...        268.0            38.29
# 18   2026-09-20    2026-09-27  ...        348.0            49.71
# 19   2026-09-20    2026-09-27  ...        350.0            50.00
# 20   2026-09-20    2026-09-27  ...        340.0            48.57
#
#    price_per_adult  price_per_adult_per_night  rating  quality_price_score  \
# 0             64.2                       9.17     8.7             0.726084
# 1             56.8                       8.11     8.7             0.821298
# 2             70.0                      10.00     9.5             0.727046
# 3             72.0                      10.29    10.0             0.743799
# 4             71.4                      10.20     9.8             0.735327
# 5             66.4                       9.49    10.0             0.806703
# 6             64.2                       9.17    10.0             0.834937
# 7             52.6                       7.51     8.2             0.835985
# 8             65.4                       9.34     9.7             0.795034
# 9             60.2                       8.60     8.6             0.765438
# 10            72.8                      10.40     9.8             0.721140
# 11            53.6                       7.66    10.0             1.000000
# 12            65.4                       9.34    10.0             0.819697
# 13            59.6                       8.51     9.3             0.836718
# 14            61.0                       8.71    10.0             0.879160
# 15            36.2                       5.17     6.6             0.977819
# 16            71.4                      10.20     9.8             0.735327
# 17            53.6                       7.66     9.5             0.949880
# 18            69.6                       9.94     9.8             0.754624
# 19            70.0                      10.00     9.2             0.704011
# 20            68.0                       9.71     9.0             0.709294
#
#     num_reviews  num_rooms_available  is_available  \
# 0            59                 <NA>          True
# 1            12                 <NA>          True
# 2            15                 <NA>          True
# 3             2                 <NA>          True
# 4            62                 <NA>          True
# 5             5                 <NA>          True
# 6             2                 <NA>          True
# 7            47                 <NA>          True
# 8            10                 <NA>          True
# 9            18                 <NA>          True
# 10           71                 <NA>          True
# 11            6                 <NA>          True
# 12            2                 <NA>          True
# 13            3                 <NA>          True
# 14            4                 <NA>          True
# 15            5                 <NA>          True
# 16           11                 <NA>          True
# 17            2                 <NA>          True
# 18            5                 <NA>          True
# 19           51                 <NA>          True
# 20           25                 <NA>          True
#
#                                                   _pk
# 0   tiranaALBANIA/liceu_charm_apartment/20260920_2...
# 1   tiranaALBANIA/serenity_apartment_tirana/202609...
# 2   tiranaALBANIA/city_charm_and_comfort_apartment...
# 3   tiranaALBANIA/azeo_apartment_tirana/20260920_2...
# 4   tiranaALBANIA/lolas_home_tirane/20260920_20260...
# 5   tiranaALBANIA/house_75/20260920_20260927/20260509
# 6   tiranaALBANIA/new_bazar_apartment_tirane/20260...
# 7   tiranaALBANIA/cheap_and_good_by_topo/20260920_...
# 8   tiranaALBANIA/apartment_1330/20260920_20260927...
# 9   tiranaALBANIA/1_bed_room_apartment_don_bosko_t...
# 10  tiranaALBANIA/geljus_apartment_2/20260920_2026...
# 11  tiranaALBANIA/the_heritage_villa_tirana/202609...
# 12  tiranaALBANIA/ali_demi_apartment_tirane/202609...
# 13  tiranaALBANIA/dedja_apartment_1/20260920_20260...
# 14  tiranaALBANIA/dianahome2/20260920_20260927/202...
# 15  tiranaALBANIA/vila_masha/20260920_20260927/202...
# 16  tiranaALBANIA/sunlake_villa/20260920_20260927/...
# 17  tiranaALBANIA/damsi_loft_apartment/20260920_20...
# 18  tiranaALBANIA/villa_star_tirane/20260920_20260...
# 19  tiranaALBANIA/guest_house_banaj/20260920_20260...
# 20  tiranaALBANIA/city_center_apartment_tirane12/2...
#
# [21 rows x 23 columns]

# %%
# Cheapest available hotels in Amsterdam
df = bl.query("""
with 
    bronze_fetched as (
        select
            name, 
            search_area, 
            total_price, 
            date_diff('day', cast(checkin_date as date), cast(checkout_date as date)) as num_nights,
            round(total_price / date_diff('day', cast(checkin_date as date), cast(checkout_date as date)), 2) as price_per_night,
            round(total_price / num_adults, 2) as price_per_person,
            round(total_price / (date_diff('day', cast(checkin_date as date), cast(checkout_date as date)) * num_adults), 2) as price_per_night_per_person,
            rating, 
            round(rating / round(total_price / (date_diff('day', cast(checkin_date as date), cast(checkout_date as date)) * num_adults), 2), 2) as quality_score, 
            num_reviews, 
            distance_from_center_km, 
            num_rooms_available, 
            neighbourhood, 
            accommodation_type, 
            tags
        from bronze
        where search_area like '%Italy'
    )
    select
        name,
        search_area,
        total_price,
        price_per_night,
        price_per_person,
        price_per_night_per_person,
        rating,
        (quality_score - MIN(quality_score) OVER ()) / NULLIF(MAX(quality_score) OVER () - MIN(quality_score) OVER (), 0) AS quality_score,
        num_reviews,
        distance_from_center_km,
        num_rooms_available,
        neighbourhood,
        accommodation_type,
        tags     
    from bronze_fetched where quality_score is not null order by quality_score desc
              
"""
)
df
# Out:
#                                                   name  search_area  \
# 0                         Luxury Ludo House Trastevere  Roma__Italy
# 1                                      La Casa di Roma  Roma__Italy
# 2                            Bibbi's House San Lorenzo  Roma__Italy
# 3                                Star City Guest House  Roma__Italy
# 4                           Statonia Terrace Penthouse  Roma__Italy
# ..                                                 ...          ...
# 768         CS Central Station Termini Monti Apartment  Roma__Italy
# 769                       Lussuosa casa zona esquilino  Roma__Italy
# 770                                   Roma Guest House  Roma__Italy
# 771                 La Dolce Vita Boutique Guest House  Roma__Italy
# 772  Anantara Palazzo Naiadi Rome Hotel - A Leading...  Roma__Italy
#
#      total_price  price_per_night  price_per_person  \
# 0          874.0           145.67            218.50
# 1          905.0           150.83            226.25
# 2          999.0           166.50            249.75
# 3          787.0           131.17            196.75
# 4         1033.0           172.17            258.25
# ..           ...              ...               ...
# 768       2597.0           432.83            649.25
# 769       3814.0           635.67            953.50
# 770      12162.0          2027.00           3040.50
# 771      28760.0          4793.33           7190.00
# 772      68334.0         11389.00          17083.50
#
#      price_per_night_per_person  rating  quality_score  num_reviews  \
# 0                         36.42     9.4       1.000000         <NA>
# 1                         37.71     8.6       0.884615         <NA>
# 2                         41.63     9.0       0.846154         <NA>
# 3                         32.79     7.2       0.846154         <NA>
# 4                         43.04     9.4       0.846154         <NA>
# ..                          ...     ...            ...          ...
# 768                      108.21     2.0       0.076923         <NA>
# 769                      158.92     3.8       0.076923         <NA>
# 770                      506.75     4.2       0.038462         <NA>
# 771                     1198.33     9.3       0.038462         <NA>
# 772                     2847.25     8.9       0.000000         <NA>
#
#      distance_from_center_km  num_rooms_available neighbourhood  \
# 0                        4.0                 <NA>          None
# 1                        4.9                 <NA>          None
# 2                        0.8                 <NA>          None
# 3                        NaN                 <NA>          None
# 4                        2.5                 <NA>          None
# ..                       ...                  ...           ...
# 768                      0.6                 <NA>          None
# 769                      0.6                 <NA>          None
# 770                      NaN                 <NA>          None
# 771                      1.1                 <NA>          None
# 772                      NaN                 <NA>          None
#
#     accommodation_type           tags
# 0                 None            NaN
# 1                 None   Free parking
# 2                 None            NaN
# 3                 None            NaN
# 4                 None            NaN
# ..                 ...            ...
# 768               None            NaN
# 769               None            NaN
# 770               None            NaN
# 771               None            NaN
# 772               None  Swimming pool
#
# [773 rows x 14 columns]

# %%
bl = BronzeLayer("data")

# Cheapest available hotels in Amsterdam
df = bl.query("""
    with query as (
        select
            facility_id,
            name,
            currency,
            search_area,
            neighbourhood,
            accommodation_type,
            tags,
            distance_from_center_km,
            date_diff('day', cast(checkin_date as date), cast(checkout_date as date)) as num_nights,
            total_price,
            round(total_price / nullif(date_diff('day', cast(checkin_date as date), cast(checkout_date as date)), 0), 2) as price_per_night,
            round((total_price) / num_adults, 2) as price_per_person,
            round((total_price) / nullif(date_diff('day', cast(checkin_date as date), cast(checkout_date as date)) * num_adults, 0), 2) as price_per_night_per_person,
            url
        from bronze
              
    )
    
    select
        *
    from query
    where
        1 = 1 
        and price_per_night_per_person <= 80
        --and (
        --      (distance_from_center_km <= 3 and search_area = 'Budapest__Hungary')
        --      or
        --      (distance_from_center_km <= 1.5 and search_area = 'Ponta_Delgada__Portugal')
        --    )

""")
df
# Out:
#                               facility_id                                name  \
# 0                   ibis-budapest-stadium               ibis Budapest Stadium
# 1                  tribe-budapest-airport              TRIBE Budapest Airport
# 2                          aquincum-hotel             Verdi Budapest Aquincum
# 3                         maria-apartment                     MARIA Apartment
# 4                                 astoria  Danubius Hotel Astoria City Center
# ..                                    ...                                 ...
# 158       casa-serafina-in-prati-district     Casa Serafina in Prati district
# 159     la-lanterna-di-san-pietro-b-amp-b           La Lanterna Di San Pietro
# 160           da-adriana-al-vaticano-roma              Da Adriana al vaticano
# 161  elisas-trevi-fountain-buddyrent-roma    Elisa's Trevi Fountain BuddyRent
# 162       le-suites-del-duca-c-roma-prati   Le Suites del Duca C - Roma Prati
#
#     currency        search_area  distance_from_center_km  num_nights  \
# 0          €  Budapest__Hungary                      4.0           3
# 1          €  Budapest__Hungary                     17.2           3
# 2          €  Budapest__Hungary                      4.5           3
# 3          €  Budapest__Hungary                      1.2           3
# 4          €  Budapest__Hungary                      NaN           3
# ..       ...                ...                      ...         ...
# 158        €        Rome__Italy                      3.2          14
# 159        €        Rome__Italy                      3.4          14
# 160        €        Rome__Italy                      2.8          14
# 161        €        Rome__Italy                      0.8          14
# 162        €        Rome__Italy                      1.4          14
#
#      total_price  price_per_night  price_per_person  \
# 0          472.0           157.33            157.33
# 1          576.0           192.00            192.00
# 2          553.0           184.33            184.33
# 3          216.0            72.00             72.00
# 4          471.0           157.00            157.00
# ..           ...              ...               ...
# 158       2884.0           206.00            576.80
# 159       4707.0           336.21            941.40
# 160       2926.0           209.00            585.20
# 161       4973.0           355.21            994.60
# 162       4237.0           302.64            847.40
#
#      price_per_night_per_person  \
# 0                         52.44
# 1                         64.00
# 2                         61.44
# 3                         24.00
# 4                         52.33
# ..                          ...
# 158                       41.20
# 159                       67.24
# 160                       41.80
# 161                       71.04
# 162                       60.53
#
#                                                    url
# 0    https://www.booking.com/hotel/hu/ibis-budapest...
# 1    https://www.booking.com/hotel/hu/tribe-budapes...
# 2    https://www.booking.com/hotel/hu/aquincum-hote...
# 3    https://www.booking.com/hotel/hu/maria-apartme...
# 4    https://www.booking.com/hotel/hu/astoria.en-gb...
# ..                                                 ...
# 158  https://www.booking.com/hotel/it/casa-serafina...
# 159  https://www.booking.com/hotel/it/la-lanterna-d...
# 160  https://www.booking.com/hotel/it/da-adriana-al...
# 161  https://www.booking.com/hotel/it/elisas-trevi-...
# 162  https://www.booking.com/hotel/it/le-suites-del...
#
# [163 rows x 11 columns]

# %%
df
# Out:
#                                                   url
# 0   https://www.booking.com/hotel/hu/aquaworld-res...
# 1   https://www.booking.com/hotel/hu/ibis-budapest...
# 2   https://www.booking.com/hotel/hu/tribe-budapes...
# 3   https://www.booking.com/hotel/hu/aquincum-hote...
# 4   https://www.booking.com/hotel/hu/maria-apartme...
# ..                                                ...
# 57  https://www.booking.com/hotel/pt/the-rock-gues...
# 58  https://www.booking.com/hotel/pt/solar-dos-can...
# 59  https://www.booking.com/hotel/pt/acores-atlant...
# 60  https://www.booking.com/hotel/pt/guestready-ga...
# 61  https://www.booking.com/hotel/pt/sao-miguel-pa...
#
# [62 rows x 1 columns]
